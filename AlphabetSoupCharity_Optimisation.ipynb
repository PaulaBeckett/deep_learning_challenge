# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
count_values = application_df['APPLICATION_TYPE'].value_counts()
count_values
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = count_values.loc[count_values < 1000].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
# looked for those above 10 as per instructions
classification_above_1 = classification_counts.loc[classification_counts > 10]
classification_above_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_counts.loc[classification_counts < 250].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1197
# C7000      777
# C1700      287
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       1
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  AFFILIATION_CompanySponsored  \
# 0                    0                    0                             0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df.IS_SUCCESSFUL.values
X = application_df.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimisation Attempt 1
#
# > Preprocessing same as initial training model
#
# > Additional hidden layer
#
# > Reduced Epochs

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 30

nn_1 = tf.keras.models.Sequential()

# First hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

#additional optimisation layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn_1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_1.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_29 (Dense)            (None, 80)                3440
#
#  dense_30 (Dense)            (None, 30)                2430
#
#  dense_31 (Dense)            (None, 30)                930
#
#  dense_32 (Dense)            (None, 1)                 31
#
# ...
# Total params: 6,831
# Trainable params: 6,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_1.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5683 - accuracy: 0.7245
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5556 - accuracy: 0.7307
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7313
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7329
# Epoch 5/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5495 - accuracy: 0.7345
# Epoch 6/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5495 - accuracy: 0.7354
# Epoch 7/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5485 - accuracy: 0.7348
# Epoch 8/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5476 - accuracy: 0.7342
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7360
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5609 - accuracy: 0.7238 - 697ms/epoch - 3ms/step
# Loss: 0.5608630776405334, Accuracy: 0.7238484025001526

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimisation Attempt 2
#
# > Preprocessing same as initial training model
#
# > Keep additional hidden layer from first attempt which saw a small increase in accuracy
#
#
# > Switched to activation 'tanh' for hidden layers

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 30

nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='tanh'))

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='tanh'))

#additional optimisation layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_37 (Dense)            (None, 80)                3440
#
#  dense_38 (Dense)            (None, 30)                2430
#
#  dense_39 (Dense)            (None, 30)                930
#
#  dense_40 (Dense)            (None, 1)                 31
#
# ...
# Total params: 6,831
# Trainable params: 6,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_2.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5690 - accuracy: 0.7239
# Epoch 2/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7306
# Epoch 3/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5533 - accuracy: 0.7325
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7320
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7327
# Epoch 6/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7342
# Epoch 7/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7355
# Epoch 8/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7339
# Epoch 9/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5464 - accuracy: 0.7347
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5621 - accuracy: 0.7245 - 426ms/epoch - 2ms/step
# Loss: 0.5621394515037537, Accuracy: 0.7245481014251709

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimisation Attempt 3
#
# > Preprocessing same as initial training model
#
# > Keep additional hidden layer from first attempt which saw a small increase in accuracy
#
#
# > Keep 'tanh' activation for hidden layers from second attempt as there was another small increase in accuracy
#
# > Reduce units in hidden layers to assess for overfitting

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 5
hidden_nodes_layer3 = 2

nn_3 = tf.keras.models.Sequential()

# First hidden layer
nn_3.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='tanh'))

# Second hidden layer
nn_3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='tanh'))

#additional optimisation layer
nn_3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Output layer
nn_3.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_41 (Dense)            (None, 10)                430
#
#  dense_42 (Dense)            (None, 5)                 55
#
#  dense_43 (Dense)            (None, 2)                 12
#
#  dense_44 (Dense)            (None, 1)                 3
#
# ...
# Total params: 500
# Trainable params: 500
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_3.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5963 - accuracy: 0.7035
# Epoch 2/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5696 - accuracy: 0.7291
# Epoch 3/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5626 - accuracy: 0.7311
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5591 - accuracy: 0.7320
# Epoch 5/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5574 - accuracy: 0.7319
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7322
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5548 - accuracy: 0.7322
# Epoch 8/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5538 - accuracy: 0.7325
# Epoch 9/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5532 - accuracy: 0.7332
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5600 - accuracy: 0.7227 - 625ms/epoch - 2ms/step
# Loss: 0.5600340962409973, Accuracy: 0.7226822376251221

# %%
# Export our model to HDF5 file
#save model 2 with the highest accuracy
nn_2.save('AlphabetSoupCharity_Optimisation.h5')
